# %%
import pandas as pd
import os

# %%
RT_df = pd.read_csv('./Resources/ReachedTablesData.csv', header = 2)
RT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4713 entries, 0 to 4712
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     328 non-null    object
#  1   Unnamed: 1     306 non-null    object
#  2   Unnamed: 2     306 non-null    object
#  3   Unnamed: 3     306 non-null    object
#  4   Tons to Egypt  3542 non-null   object
#  5    3197.0        3378 non-null   float64
#  6   From Albania   3345 non-null   object
#  7    60.0          3345 non-null   float64
#  8   Unnamed: 8     0 non-null      float64
# dtypes: float64(3), object(6)
# memory usage: 331.5+ KB

# %%
RT_df.filter(regex='Unnamed').dropna(how='all').head(32)
# Out:
#                  Unnamed: 0      Unnamed: 1         Unnamed: 2  \
# 16             Country Name   Tons Exported   End in the Ocean
# 17                  algeria          100568            28034.0
# 40             Country Name   Tons Exported   End in the Ocean
# 41                   angola           20827              172.0
# 80             Country Name   Tons Exported   End in the Ocean
# 81      antigua and barbuda             157               80.0
# 104            Country Name   Tons Exported   End in the Ocean
# 105               argentina            8088             6283.0
# 130            Country Name   Tons Exported   End in the Ocean
# 131               australia            1623              432.0
# 179            Country Name   Tons Exported   End in the Ocean
# 180                 bahrain              81                1.0
# 184            Country Name   Tons Exported   End in the Ocean
# 185              bangladesh          175902            43896.0
# ...
